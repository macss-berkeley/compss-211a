# %% [markdown]
# # Week 11 live workspace: cloud environments and reproducibility
#
# Last week we evaluated model output. Now we need to account for where the computation ran and what another person would need to run it again. We will compare local Jupyter, a hosted Colab runtime, and the Gemini API without treating any one environment as universally superior.

# %% [markdown]
# ## Today
#
# - Identify where code, data, model weights, credentials, and outputs live.
# - Capture evidence about a runtime and GPU.
# - Observe ephemeral state and restore it reproducibly.
# - Treat a Gemini call as a remote-service boundary with quota and cost implications.
# - Turn one project blocker into evidence, an owner, an action, and a deadline.
#
# Keep [the cloud runtime and reproducibility guide](cloud_runtime_reproducibility_guide.md) open for durable reference.

# %%
# Safe, offline setup. We will add substantive code together.
from datetime import datetime, timezone
from hashlib import sha256
from importlib.metadata import PackageNotFoundError, version
from pathlib import Path
import json
import os
import platform
import sys
import time

RUN_LIVE_GEMINI = False  # Change only during the instructor-led bounded call.
GEMINI_MODEL = "gemini-3.6-flash"
SMALL_OPEN_MODEL = "Qwen/Qwen2.5-0.5B-Instruct"

print("Setup ready. No credential or network request was used.")

# %% [markdown]
# ## 1. Three execution models
#
# For each scenario, predict whether Python and model inference run locally, in a Colab virtual machine, or in the Gemini service. Track where the data and credentials cross a boundary.

# %% [markdown]
# ## 2. Local and Colab environment manifests
#
# We will create the same manifest in both environments, save it as JSON, and compare consequential differences. A manifest records evidence; it does not contain secrets.

# %% [markdown]
# ## 3. Predict runtime state
#
# Before the demonstration, predict what survives `Disconnect and delete runtime`: the saved notebook, a file under `/content`, a runtime-only package, Python variables, a mounted Drive file, and a Colab user secret.

# %% [markdown]
# ## 4. GPU use and a small model inference
#
# Selecting a GPU runtime is not proof that code used it. We will inspect tensor and model devices, time work correctly, and record one small open-weight inference. An offline record is available if accelerator access or model download fails.

# %% [markdown]
# ## 5. Ephemeral-state failure and repair
#
# We will create a temporary artifact, examine a before/after reset record, provoke a missing-state failure, and restore the environment from a documented bootstrap.

# %% [markdown]
# ## 6. Gemini as a remote-service boundary
#
# The class call uses a fixed number of synthetic examples. We will confirm that a secret is available without displaying it, record usage metadata, and separate input from output cost exposure. The offline path never reads a key or contacts the service.

# %% [markdown]
# ## 7. Project blocker triage
#
# Replace the placeholders with one real team-project blocker.
#
# - **Blocker:**
# - **Reproduction steps:**
# - **Expected:**
# - **Observed:**
# - **Evidence:**
# - **Scope or impact:**
# - **Owner:**
# - **Next action:**
# - **Deadline:**
# - **Done when:**

# %% [markdown]
# ## Exit retrieval
#
# 1. What evidence proves that a model ran on a GPU?
# 2. Name two things a Colab reset can invalidate.
# 3. Rewrite "the API does not work" as evidence plus one next action.
