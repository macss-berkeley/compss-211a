# %% [markdown]
# # Week 7 live workspace: Agentic code verification
#
# Treat generated code as a draft that needs checking. We will save the original output, write a contract, test a hand-checkable case, repair the smallest defect we can justify, and record what remains uncertain. Keep the [agentic code verification guide](agentic_code_verification_guide.md) open as the week's reference.
#
# We wrote the data for this exercise. They do not describe Berkeley services or people.

# %%
import pandas as pd

service_waits = pd.DataFrame(
    {
        "case_id": ["F-001", "F-002", "F-003", "F-004", "F-005", "F-006"],
        "channel": ["web", "web", "walk_in", "walk_in", "walk_in", "phone"],
        "minutes": [4.0, 8.0, 2.0, 6.0, 10.0, None],
    }
)
service_waits

# %% [markdown]
# ## 1. Preserve the prompt and raw generated output
#
# Paste the captured prompt and code exactly as received. Do not repair it yet.

# %% [markdown]
# ## 2. State the contract
#
# Write the expected inputs, output, invariants, missing-value behavior, mutation policy, error behavior, and what is out of scope.

# %% [markdown]
# **Contract:**
#
# - Inputs:
# - Output:
# - Invariants:
# - Missing-value and edge-case behavior:
# - Mutation policy:
# - Error behavior:
# - Out of scope:

# %% [markdown]
# ## 3. Predict, run, and inspect
#
# Calculate at least one expected result by hand before running the generated function. Then record what is plausible and what is wrong.

# %% [markdown]
# ## 4. Write tests
#
# Test structure, semantic behavior including an edge case, and non-mutation. Confirm that a failure occurs for the reason named in the contract.

# %% [markdown]
# ## 5. Repair only the demonstrated defect
#
# Change only the defect supported by the evidence. Rerun every test and inspect the change.

# %% [markdown]
# ## 6. Evidence note
#
# Record the tool/model/date, prompt, failing evidence, repair, passing evidence, documentation checked, side effects considered, technical debt, epistemic debt, and remaining uncertainty.

# %% [markdown]
# **Evidence note:**
#
# - Tool/model/date:
# - Prompt and raw output preserved at:
# - Failing evidence:
# - Repair:
# - Passing evidence:
# - Documentation checked:
# - Credentials, privacy, cost, and side effects:
# - Technical debt:
# - Epistemic debt:
# - Remaining uncertainty:
