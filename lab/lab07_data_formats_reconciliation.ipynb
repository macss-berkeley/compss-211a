# %% [markdown]
# # Lab 7: Berkeley Data-Format Reconciliation
#
# **COMPSS 211 | Fall 2026 | Student copy**
#
# Compare equivalent campus-edge records in JSON, CSV, TSV, and XML after the structured-data lecture.
#
# **Date/deadline:** Friday, October 9, 2026
#
# Student starter: complete every task and replace each response placeholder.

# %% [markdown]
# ## Scenario
#
# You are working in the fictional Berkeley Methods Studio. The exercise uses synthetic or bounded public data and does not make claims about actual Berkeley students, employees, or campus operations.
#
# The Berkeley Methods Studio is fictional. Synthetic data are labeled
# as synthetic; public snapshots retain source and filter notes.

# %% [markdown]
# ## Goal
#
# - Load four formats.
# - Normalize types and column order.
# - Locate and explain a mismatch.

# %% [markdown]
# ## Resources you need
#
# - **Timing:** 10/40/10 discussion structure.
# - **Quiz:** The exit quiz covers Monday's lecture, not new material.

# %%
from pathlib import Path
import json
import os
import sys

import pandas as pd
import numpy as np
from IPython.display import display

REQUIRED_PYTHON = "3.14.6"
if sys.version.split()[0] != REQUIRED_PYTHON:
    raise RuntimeError(
        f"This notebook requires Python {REQUIRED_PYTHON}; "
        f"the active kernel is {sys.version.split()[0]}."
    )

COURSE_ROOT = Path.cwd()
DATA_DIR = COURSE_ROOT / "assignments" / "notebooks" / "data"
GENERATED_DIR = COURSE_ROOT / "assignments" / "notebooks" / "generated"
GENERATED_DIR.mkdir(parents=True, exist_ok=True)
print(f"Python {sys.version.split()[0]} | data={DATA_DIR}")

# %% [markdown]
# ## Practice: compare four representations

# %%
from xml.etree import ElementTree as ET

# %%
csv_rows = pd.read_csv(DATA_DIR / "hw3_campus_edge_311_2025.csv", dtype={"case_id": str})
tsv_rows = pd.read_csv(DATA_DIR / "hw3_campus_edge_311_2025.tsv", sep="\t", dtype={"case_id": str})
json_rows = pd.read_json(DATA_DIR / "hw3_campus_edge_311_2025.json", dtype={"case_id": str})
xml_root = ET.parse(DATA_DIR / "hw3_campus_edge_311_2025.xml").getroot()
xml_rows = pd.DataFrame([{child.tag: child.text for child in item} for item in xml_root])
format_audit = pd.DataFrame({
    "csv": [len(csv_rows), csv_rows["case_id"].nunique()],
    "tsv": [len(tsv_rows), tsv_rows["case_id"].nunique()],
    "json": [len(json_rows), json_rows["case_id"].nunique()],
    "xml": [len(xml_rows), xml_rows["case_id"].nunique()],
}, index=["rows", "unique_cases"]).T
display(format_audit)

# %% [markdown]
# ### Student response
#
# **Prompt:** Write one concrete thing you can now do and one question you still have.
#
# > Replace this text with your response.

# %% [markdown]
# ## Exit
#
# This notebook is practice only. Regular discussions use the first
# 10 minutes for the previous quiz, the middle 40 minutes for this lab,
# and the final 10 minutes for the current three-question quiz.
