# %% [markdown]
# # Optional Week 0: Pre-Lecture Onboarding and Access Check
#
# **COMPSS 211 | Fall 2026 | Student copy**
#
# Establish access before the first lecture; no quiz is administered.
#
# **Date/deadline:** Friday, August 28, 2026
#
# Work through each task and replace the response placeholders with your own answers.

# %% [markdown]
# ## Scenario
#
# This meeting is for access and installation, not new course content. Follow `SETUP.md` until you can open the complete repository in VS Code and run a notebook cell with the repository's `.venv` kernel. If something fails, record the first failing step before trying another fix.

# %% [markdown]
# ## Goal
#
# - Open the repository and bCourses.
# - Select the course `.venv` as the VS Code interpreter and notebook kernel.
# - Diagnose paths and package versions.

# %% [markdown]
# ## Keep handy
#
# - **Timing:** Full 60-minute onboarding session.
# - **Support:** Record the first failing check rather than reinstalling at random.

# %%
from pathlib import Path
import json
import os
import sys

import pandas as pd
import numpy as np
from IPython.display import display

SUPPORTED_PYTHON = (3, 13)
if sys.version_info[:2] != SUPPORTED_PYTHON:
    print(
        "Setup note: this course is tested with Python 3.13; "
        f"you are running {sys.version.split()[0]}."
    )

def find_course_root():
    """Find the cloned repository when this notebook is running locally."""
    for folder in (Path.cwd(), *Path.cwd().parents):
        if (folder / "pyproject.toml").exists() and (folder / "data").is_dir():
            return folder
    return None

LOCAL_COURSE_ROOT = find_course_root()
COURSE_ROOT = LOCAL_COURSE_ROOT or Path.cwd()
DATA_DIR = (
    LOCAL_COURSE_ROOT / "data"
    if LOCAL_COURSE_ROOT
    else COURSE_ROOT / "compss211_data"
)
GENERATED_DIR = COURSE_ROOT / "generated"
DATA_DIR.mkdir(parents=True, exist_ok=True)
GENERATED_DIR.mkdir(parents=True, exist_ok=True)

DATA_BASE_URL = (
    "https://raw.githubusercontent.com/"
    "macss-berkeley/compss-211a/main/data"
)

def course_data_path(filename):
    """Use a local course file, or download it when running in Colab."""
    path = DATA_DIR / filename
    if not path.exists():
        from urllib.request import urlretrieve

        urlretrieve(f"{DATA_BASE_URL}/{filename}", path)
    return path

print(f"Python {sys.version.split()[0]} | data={DATA_DIR}")

# %% [markdown]
# ## Practice: access and environment

# %%
access_record = {
    "repository_open": LOCAL_COURSE_ROOT is not None,
    "uv_lock_found": bool(
        LOCAL_COURSE_ROOT and (LOCAL_COURSE_ROOT / "uv.lock").exists()
    ),
    "project_environment": Path(sys.prefix).name == ".venv",
    "bcourses_open": False,
    "local_editor": "VS Code",
    "notebook_kernel": "project .venv",
    "python": sys.version.split()[0],
}
display(pd.Series(access_record))

# %% [markdown]
# ### Your notes
#
# Before you leave, write down one thing you can now do and one question you still have.
#
# > Write your notes here.

# %% [markdown]
# ## Exit
#
# There is no quiz today. If setup is not complete, save the first failing check and bring it to office hours or the next support session.
