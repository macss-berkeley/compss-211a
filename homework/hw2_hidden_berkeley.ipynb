# %% [markdown]
# # HW2: Hidden Berkeley
#
# **COMPSS 211 | Fall 2026 | Student copy**
#
# Build and publish a small field guide while demonstrating a traceable Git, GitHub Desktop, command-line, and GitHub Pages workflow.
#
# **Date/deadline:** Sunday, October 4, 2026 at 11:59 p.m.
#
# Complete every required function and written response. Keep the named outputs so the notebook checks can find them.

# %% [markdown]
# ## Scenario
#
# The fictional Berkeley Methods Studio is assembling a public guide to campus resources that newcomers often discover late. Start from the supplied public catalog, build the page, and leave a Git history that another person can follow. Do not add private contacts, schedules, access codes, or student information.

# %% [markdown]
# ## What you will practice
#
# - Generate valid HTML and repository documentation.
# - Make at least three coherent commits with descriptive messages.
# - Explain commit, push, branch, remote, and Pages deployment.
# - Verify the public URL without exposing private information.

# %% [markdown]
# ## Keep handy
#
# - **Git:** Inspect state before acting: `git status`, `git diff`, then `git log --oneline`.
# - **Pages:** Publish from a clearly identified branch and folder; verify in a private browser window.
# - **Safety:** Do not publish schedules, access codes, student data, or private contact details.
# - **Documentation:** Git reference: https://git-scm.com/docs

# %% [markdown]
# ## AI and collaboration policy
#
# AI may assist with optional wording or CSS only when disclosed. It may not perform or fabricate the required repository workflow.

# %%
from pathlib import Path
import json
import os
import sys

import html
import pandas as pd
from IPython.display import HTML, display

SUPPORTED_PYTHON = (3, 13)
if sys.version_info[:2] != SUPPORTED_PYTHON:
    print(
        "Setup note: this course is tested with Python 3.13; "
        f"you are running {sys.version.split()[0]}."
    )

def find_course_root():
    """Find the cloned repository when this notebook is running locally."""
    for folder in (Path.cwd(), *Path.cwd().parents):
        if (folder / "pyproject.toml").exists() and (folder / "data").is_dir():
            return folder
    return None

LOCAL_COURSE_ROOT = find_course_root()
COURSE_ROOT = LOCAL_COURSE_ROOT or Path.cwd()
DATA_DIR = (
    LOCAL_COURSE_ROOT / "data"
    if LOCAL_COURSE_ROOT
    else COURSE_ROOT / "compss211_data"
)
GENERATED_DIR = COURSE_ROOT / "generated"
DATA_DIR.mkdir(parents=True, exist_ok=True)
GENERATED_DIR.mkdir(parents=True, exist_ok=True)

DATA_BASE_URL = (
    "https://raw.githubusercontent.com/"
    "macss-berkeley/compss-211a/main/data"
)

def course_data_path(filename):
    """Use a local course file, or download it when running in Colab."""
    path = DATA_DIR / filename
    if not path.exists():
        from urllib.request import urlretrieve

        urlretrieve(f"{DATA_BASE_URL}/{filename}", path)
    return path

print(f"Python {sys.version.split()[0]} | data={DATA_DIR}")

# %% [markdown]
# ## 1. Inspect the safe catalog
#
# The supplied table contains eight public Berkeley resources. Use all
# eight rows. Do not add access codes, private contact details, student
# information, or operational claims that are not on an official page.

# %%
locations = pd.read_csv(course_data_path("hw2_hidden_berkeley_locations.csv"))
display(locations)
PAGE_STYLE = '''
body { max-width: 900px; margin: 2rem auto; padding: 0 1rem;
       font: 17px/1.55 system-ui; color: #1f1f1f; }
main { display: grid; grid-template-columns:
       repeat(auto-fit, minmax(240px, 1fr)); gap: 1rem; }
article { border-top: 4px solid #FDB515; padding: 1rem;
          background: #f7f7f7; }
a { color: #003262; }
'''

# %% [markdown]
# ## 2. Render one location card
#
# Implement `render_location_card(row)`.
#
# **Required output:** `card_preview`, a single `<article>` containing
# all five public fields and an `Official source` link. Characters such
# as `&`, `<`, `>`, and quotation marks must be safely escaped.

# %%
def render_location_card(row):
    """Return one escaped HTML <article> for a location row.

    Include the name, category, area, access note, and official source
    URL. Escape every value inserted into HTML.
    """
    raise NotImplementedError("Implement render_location_card")

# %%
# Create card_preview from the first row and display it as HTML.

# %% [markdown]
# ## 3. Build the complete field guide
#
# Implement `build_field_guide(frame, title, intro)`.
#
# **Required output:** `html_document`, a complete HTML5 document with
# one card for each of the eight rows, one page heading, an introduction,
# the supplied CSS, and a responsive viewport declaration.

# %%
def build_field_guide(frame, title, intro):
    """Return a complete HTML5 document.

    Call render_location_card once per row. Include an escaped title and
    introduction, PAGE_STYLE, and one <main> containing all cards.
    """
    raise NotImplementedError("Implement build_field_guide")

# %%
# Choose a title and two-sentence introduction, then create and
# display html_document using all eight locations.

# %% [markdown]
# ## 4. Write the site files
#
# Implement `write_site(site_dir, html_text, readme_text)`.
#
# **Required output:** `index_path` and `readme_path` inside
# `generated/hw2_hidden_berkeley_site`.
# The README must name the project, describe the data source, and explain
# how to open or deploy the page.

# %%
def write_site(site_dir, html_text, readme_text):
    """Write index.html and README.md and return both Path objects."""
    raise NotImplementedError("Implement write_site")

# %%
# Write a useful README_TEXT, call write_site, and display both paths.

# %% [markdown]
# ## 5. Publish and document the workflow
#
# Move the generated site files into your assignment repository. Make at
# least three coherent commits, push them, publish with GitHub Pages, and
# verify the public URL in a private browser window.

# %%
REPOSITORY_URL = ""
PAGES_URL = ""
GIT_LOG = ""

# %% [markdown]
# ### Your response
#
# **Prompt:** In four to six sentences, explain how the commit history, remote repository, and Pages URL establish the workflow. End with your AI use disclosure.
#
# > Write your response here, then delete this instruction.
