# %% [markdown]
# # HW2: Hidden Berkeley
#
# **COMPSS 211A · Fall 2026 · Student copy**
#
# **Why “Hidden Berkeley”?** This assignment is a small guide for someone new to Berkeley who may not yet know about its libraries, museums, and student services. “Hidden” means easy to overlook when you are new. For example, the guide includes Morrison Library and the UC Botanical Garden.
#
# We have supplied a list of eight places and services, along with a ready-made webpage containing that information. You will add an introduction for your readers and publish your own version of the guide. Each entry includes a link to an official webpage so readers can check current details, including who can use the resource.
#
# Goal: edit a supplied Markdown page, publish it, and document a Git workflow another person can follow.
#
# **Due:** Sunday, October 4, 2026 at 11:59 p.m. Pacific.
#
# Note: writing HTML or CSS is an optional extension.

# %% [markdown]
# ## What you will practise
#
# - Read the supplied table of eight Berkeley places and services.
# - Edit the guide's introduction and a README—the short document that explains your project—using Markdown.
# - Record at least three sets of related changes as commits in **your own HW2 website repository**, using GitHub Desktop. Push those commits to GitHub.
# - Publish the guide with GitHub Pages and check that readers can see your changes and follow the links to the official webpages.
# - Explain where your work lives on your computer, on GitHub, and on the published website.
#
# Open this notebook from your local course repository in VS Code. Run the supplied setup cell below with the course Python kernel. You will use GitHub Desktop and GitHub.com for the website repository.

# %% [markdown]
# ## AI and collaboration policy
#
# Please don't use AI to perform or fabricate the required repository workflow. Complete and explain your own work.
#
# Use the supplied public resource information.

# %%
# Supplied setup: run this cell. You do not need to rewrite it.
from pathlib import Path
from zipfile import ZipFile
import pandas as pd
from IPython.display import display, Markdown

def find_course_root():
    for folder in (Path.cwd(), *Path.cwd().parents):
        if (folder / "pyproject.toml").is_file() and (folder / "data").is_dir():
            return folder
    raise FileNotFoundError("Open the complete course repository in VS Code first.")

COURSE_ROOT = find_course_root()
DATA_DIR = COURSE_ROOT / "data"
GENERATED_DIR = COURSE_ROOT / "generated"
GENERATED_DIR.mkdir(exist_ok=True)

def prepare_site(destination):
    # These are the four supplied files. Existing edits are preserved on rerun.
    names = ["README.md", "docs/index.md", "docs/_config.yml", "docs/_layouts/default.html"]
    with ZipFile(DATA_DIR / "hw2_hidden_berkeley_site_starter.zip") as starter:
        for name in names:
            path = destination / name
            path.parent.mkdir(parents=True, exist_ok=True)
            if not path.exists():
                path.write_bytes(starter.read(name))
    return destination / "docs/index.md", destination / "README.md"

# %% [markdown]
# ## 1. Read the supplied list of Berkeley resources
#
# The course repository includes a CSV file at `data/hw2_hidden_berkeley_locations.csv`. This is the list you will use for the guide. The next cell reads that file into a table called `locations` and displays it.
#
# Each of its eight rows describes one place or service. Read the following information for each entry:
#
# - `name`: the place or service, such as Morrison Library.
# - `category` and `area`: what kind of resource it is and where it is located.
# - `access_note`: information about using the resource, including any instruction to check current access details.
# - `source_url`: a link to the resource's official webpage, where readers can check those details.
#
# The `location_id` column gives each row a short identifier. The supplied webpage already contains all eight entries, including their names, categories, areas, access notes, and official links. Keep that information when editing the guide: it helps readers decide whether a resource is useful to them and where to learn more.

# %%
locations = pd.read_csv(DATA_DIR / "hw2_hidden_berkeley_locations.csv")
display(locations)

# %% [markdown]
# ## 2. Prepare the webpage and your own repository
#
# The next cell copies the supplied webpage files into `generated/hw2_hidden_berkeley_site` inside your local course repository. It prints the folder's location so you can find it. Running the cell again leaves existing files and edits in that folder intact.
#
# After running the cell:
#
# 1. Create your own separate repository for this website using GitHub Desktop. You can name it `hidden-berkeley`. If you already created an HW2 repository, use that one.
# 2. From the generated folder, copy `README.md` and the complete `docs/` folder into the **top-level folder of your HW2 repository**. That folder should now contain both `README.md` and `docs/`. If a same-named file already contains your work, compare the files before replacing it.
# 3. In GitHub Desktop, select your HW2 repository, inspect the added files, and make a first commit with a message such as `Add supplied Berkeley guide`.
#
# From this point on, edit the webpage files in **your HW2 repository**.

# %%
SITE_DIR = GENERATED_DIR / "hw2_hidden_berkeley_site"
index_path, readme_path = prepare_site(SITE_DIR)
print("Starter folder:", SITE_DIR)
print("Page:", index_path)
print("README:", readme_path)

# %% [markdown]
# ### Which file do I edit?
#
# | File in your HW2 website repository | Your work |
# |---|---|
# | `docs/index.md` | Give the guide a heading and a two-sentence introduction explaining who it is for. Keep the eight entries and their links to the official webpages. |
# | `README.md` | Explain the guide's purpose, where its information came from, how you published it, and what you checked on the finished website. |
# | `docs/_config.yml` and `docs/_layouts/default.html` | Supplied files that control the page's appearance and publication; no editing is required. |
#
# Markdown uses `#` for a heading, blank lines between paragraphs, and `[link text](URL)` for a link. Use VS Code's Markdown preview to inspect your edits. Keep the opening lines between `---` markers in `docs/index.md`; they connect the page to its supplied layout.

# %% [markdown]
# ## 3. Edit, inspect, commit, and push
#
# As you work through sections 2–4, make at least **three commits in your HW2 website repository**. A commit records a snapshot of your files in that repository's local history. Each commit should bring together changes that serve one clear purpose, with a message explaining that purpose.
#
# For example, your commits might record adding the supplied files, writing the introduction, and documenting what you checked after publishing the website. The first commit from section 2 counts toward the three. You can make the verification commit after completing section 4.
#
# For each change:
#
# 1. Edit and save the intended file in your HW2 website repository.
# 2. Select that repository in GitHub Desktop and inspect the **diff**, which shows what changed in the file. Check that it contains the changes you intended.
# 3. Commit with a message explaining the change.
# 4. Push to send the local commits to that repository on GitHub. Open the file on GitHub and confirm that your edit appears there.
#
# Keep the eight resource descriptions and their official links while editing the guide. Writing HTML is optional.

# %% [markdown]
# ## 4. Publish and verify
#
# GitHub shows your repository's files and history. **GitHub Pages** turns the files in `docs/` into a website that someone can read in a browser.
#
# In your HW2 repository on GitHub, open **Settings → Pages**. Choose **Deploy from a branch**, with branch **main** and folder **/docs**. These settings tell GitHub which files to publish. The supplied files handle the page layout; no local website-framework installation is required.
#
# Check the deployment status—the progress of GitHub building and publishing your site—then open the website address shown in Pages settings in a private browser window. Check that your heading and introduction appear, all eight entries and their access notes are present, and the official links open the intended webpages.
#
# Add a brief account of what you actually checked to the README in your HW2 repository. Commit and push that change too.
#
# If GitHub shows your edited file but the website still shows the old version, check whether the deployment has finished before editing the content again.
#
# Reference: [GitHub Pages publishing source](https://docs.github.com/en/pages/getting-started-with-github-pages/configuring-a-publishing-source-for-your-github-pages-site).

# %% [markdown]
# ## 5. Record what you did
#
# The notebook you submit needs to point to your project and show its actual commit history. Fill in the next cell:
#
# - `REPOSITORY_URL`: the GitHub address of your HW2 repository, where someone can inspect the files and history.
# - `PAGES_URL`: the address of your published guide, where someone can read the finished website.
# - `GIT_LOG`: the output of `git log --oneline`, showing the commits you made in your HW2 repository.
#
# To get that log, open a terminal in your **HW2 website repository's folder**, run `git log --oneline`, and paste the relevant output into `GIT_LOG`. Include at least three commits you made for this assignment. GitHub Desktop's History view shows the same commits and can help you check that you are looking at the right repository. Use your actual history.

# %%
REPOSITORY_URL = ""
PAGES_URL = ""
GIT_LOG = """
Paste your actual commit log here.
"""

# %% [markdown]
# ### Your response
#
# In four to six sentences, describe how one change you made moved from a file on your computer to a commit, then to GitHub and the published website. Explain one check you performed on the website and what it showed you. End with your AI-use disclosure.
#
# > Write your response here, then delete this instruction.

# %% [markdown]
# ## Submission
#
# 1. Fill `REPOSITORY_URL`, `PAGES_URL`, `GIT_LOG`, and the written response. Check that your published guide contains all eight entries and their official links, and that the README in your HW2 repository explains the project.
# 2. Restart the kernel and run the notebook from top to bottom. The supplied setup preserves existing starter files; the edits in your separate assignment repository remain there.
# 3. Save the executed notebook as `lastname_firstname_hw2.ipynb`, using lowercase letters and underscores.
# 4. Upload only that `.ipynb` file to the HW2 bCourses assignment. Do not upload a ZIP; the URLs in your notebook point to your repository and published page.
#
# No custom HTML, CSS, or HTML-generating Python functions are required for full credit.

# %% [markdown]
# ## Optional extension: write HTML or CSS
#
# If you want to explore webpage construction after completing the required work, customize the supplied HTML layout/CSS or add a separate `docs/custom.html` page and link it from the Markdown page. Keep all required resource information and source links available.
#
# You may write HTML directly or try Python functions such as `render_location_card(row)` and `build_field_guide(frame, title, intro)`. If inserting text into HTML with Python, escape it with `html.escape`. These are optional experiments; you do not need to implement `render_location_card`, `build_field_guide`, or `write_site` for the assignment.
#
# The standard Markdown page can earn full credit. Optional HTML does not add a separate submission or replace any required Git workflow or explanation. Keep experiments out of the required notebook run if they are unfinished.
